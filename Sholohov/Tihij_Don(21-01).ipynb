# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Импорты" data-toc-modified-id="Импорты-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Импорты</a></span></li><li><span><a href="#ПОСТРОИМ-ГРАФИК-РАСПРЕДЕЛЕНИЯС-СЛОВ-ПО-ЧАСТОТНОСТИ" data-toc-modified-id="ПОСТРОИМ-ГРАФИК-РАСПРЕДЕЛЕНИЯС-СЛОВ-ПО-ЧАСТОТНОСТИ-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>ПОСТРОИМ ГРАФИК РАСПРЕДЕЛЕНИЯС СЛОВ ПО ЧАСТОТНОСТИ</a></span><ul class="toc-item"><li><span><a href="#Отдельные-слова-(без-разделения-на-PoS)" data-toc-modified-id="Отдельные-слова-(без-разделения-на-PoS)-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Отдельные слова (без разделения на PoS)</a></span></li><li><span><a href="#Биграммы" data-toc-modified-id="Биграммы-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Биграммы</a></span></li><li><span><a href="#Триграммы" data-toc-modified-id="Триграммы-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Триграммы</a></span></li><li><span><a href="#Четыреграммы" data-toc-modified-id="Четыреграммы-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Четыреграммы</a></span></li></ul></li><li><span><a href="#Entities-(географические-регионы)" data-toc-modified-id="Entities-(географические-регионы)-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Entities (географические регионы)</a></span></li><li><span><a href="#Части-речи-(PoS)" data-toc-modified-id="Части-речи-(PoS)-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Части речи (PoS)</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Выводы</a></span></li></ul></div>

# %% [markdown]
# #### Импорты

# %%
import spacy
import pandas as pd
import re
from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords 
import nltk
import numpy as np
from pymystem3 import Mystem
m = Mystem() 
import matplotlib.pyplot as plt
import docx
from tqdm import tqdm
import plotly.express as px
from spacy.lang.ru.examples import sentences 
nlp = spacy.load("ru_core_news_sm")
from spacy.lang.ru.examples import sentences 
from collections import Counter
import seaborn as sns

# %% [markdown]
# #### ПОСТРОИМ ГРАФИК РАСПРЕДЕЛЕНИЯС СЛОВ ПО ЧАСТОТНОСТИ

# %% [markdown]
# Загрузим заранее лемматизированный и очищенный корпус текстов

# %%
corpus_df=pd.read_csv("C:\\Users\\Admin\\Python+ DS Practice\\Яндекс Новости\\df_tihij_don.csv",encoding = 'cp1251',sep=',', error_bad_lines=False)
#В конце текста идут сноски, не будем их брать
corpus_df=corpus_df.loc[0:19719]
#Удалим пропуски
corpus_df=corpus_df.dropna()
len(corpus_df)
# Out:
# 18982

# %%
#Переведем корпус в np.array
corpus=corpus_df.values.astype('U')
corpus=corpus.reshape(18982,)
corpus.shape
# Out:
# (18982,)

# %%
stop_words = set(stopwords.words('russian'))
print(len(stop_words))
#Добавим в стоп слова слова полученные эмпирическим путем
custom_stopwords = set(['это','весь','яя','ая','га','свой','спрашивать','становиться','отвечать','подходить','уходить','выходить','оставаться','разговор','ехать','приходить'])
print(len(custom_stopwords))
stop_words.update(custom_stopwords)
#Проверим результат обновления множества
print(len(stop_words))
# Out:
# 151
# 16
# 167

# %%
#Добавим имена главныъ героев в словарь.
main_characters = set(['григорий','аксинья','пантелей','прокофиевич','иван','алексеевич','мирон','григорьевич','сергей','платонович','гришак','пантелевич','кошевой','мишка','мелехов','прохор','зыков','митька','коршунов','сашка','степан','астахов','наталья','петро','ильинична','дуняшка','бунчук','фомин','дарья','листницкий'])

# %%
#В данной работе главные герои нас не интересуют, уберем их
stop_words.update(main_characters)

# %%
#стоп слова из интернета вопрос спроный. Например убирая слово "ваше", мы теряем фразу "ваше благородие", т.е. часть авторского стиля. 
# В дальнейшем можно вернуться к этому моменту
stopwords_from_internet_1=set(["c","а","алло","без","белый","близко","более","больше","большой","будем","будет","будете","будешь","будто","буду","будут","будь","бы","бывает","бывь","был","была","были","было","быть","в","важная","важное","важные","важный","вам","вами","вас","ваш","ваша","ваше","ваши","вверх","вдали","вдруг","ведь","везде","вернуться","весь","вечер","взгляд","взять","вид","видел","видеть","вместе","вне","вниз","внизу","во","вода","война","вокруг","вон","вообще","вопрос","восемнадцатый","восемнадцать","восемь","восьмой","вот","впрочем","времени","время","все","все еще","всегда","всего","всем","всеми","всему","всех","всею","всю","всюду","вся","всё","второй","вы","выйти","г","где","главный","глаз","говорил","говорит","говорить","год","года","году","голова","голос","город","да","давать","давно","даже","далекий","далеко","дальше","даром","дать","два","двадцатый","двадцать","две","двенадцатый","двенадцать","дверь","двух","девятнадцатый","девятнадцать","девятый","девять","действительно","дел","делал","делать","делаю","дело","день","деньги","десятый","десять","для","до","довольно","долго","должен","должно","должный","дом","дорога","друг","другая","другие","других","друго","другое","другой","думать","душа","е","его","ее","ей","ему","если","есть","еще","ещё","ею","её","ж","ждать","же","жена","женщина","жизнь","жить","за","занят","занята","занято","заняты","затем","зато","зачем","здесь","земля","знать","значит","значить","и","иди","идти","из","или","им","имеет","имел","именно","иметь","ими","имя","иногда","их","к","каждая","каждое","каждые","каждый","кажется","казаться","как","какая","какой","кем","книга","когда","кого","ком","комната","кому","конец","конечно","которая","которого","которой","которые","который","которых","кроме","кругом","кто","куда","лежать","лет","ли","лицо","лишь","лучше","любить","люди","м","маленький","мало","мать","машина","между","меля","менее","меньше","меня","место","миллионов","мимо","минута","мир","мира","мне","много","многочисленная","многочисленное","многочисленные","многочисленный","мной","мною","мог","могу","могут","мож","может","может быть","можно","можхо","мои","мой","мор","мочь","моя","моё","мы","на","наверху","над","надо","назад","наиболее","найти","наконец","нам","нами","народ","нас","начала","начать","наш","наша","наше","наши","не","него","недавно","недалеко","нее","ней","некоторый","нельзя","нем","немного","нему","непрерывно","нередко","несколько","нет","нею","неё","ни","нибудь","ниже","низко","никакой","никогда","никто","никуда","ним","ними","них","ничего","ничто","но","новый","нога","ночь","ну","нужно","нужный","нх","о","об","оба","обычно","один","одиннадцатый","одиннадцать","однажды","однако","одного","одной","оказаться","окно","около","он","она","они","оно","опять","особенно","остаться","от","ответить","отец","откуда","отовсюду","отсюда","очень","первый","перед","писать","плечо","по","под","подойди","подумать","пожалуйста","позже","пойти","пока","пол","получить","помнить","понимать","понять","пор","пора","после","последний","посмотреть","посреди","потом","потому","почему","почти","правда","прекрасно","при","про","просто","против","процентов","путь","пятнадцатый","пятнадцать","пятый","пять","работа","работать","раз","разве","рано","раньше","ребенок","решить","россия","рука","русский","ряд","рядом","с","с кем","сам","сама","сами","самим","самими","самих","само","самого","самой","самом","самому","саму","самый","свет","свое","своего","своей","свои","своих","свой","свою","сделать","сеаой","себе","себя","сегодня","седьмой","сейчас","семнадцатый","семнадцать","семь","сидеть","сила","сих","сказал","сказала","сказать","сколько","слишком","слово","случай","смотреть","сначала","снова","со","собой","собою","советский","совсем","спасибо","спросить","сразу","стал","старый","стать","стол","сторона","стоять","страна","суть","считать","т","та","так","такая","также","таки","такие","такое","такой","там","твои","твой","твоя","твоё","те","тебе","тебя","тем","теми","теперь","тех","то","тобой","тобою","товарищ","тогда","того","тоже","только","том","тому","тот","тою","третий","три","тринадцатый","тринадцать","ту","туда","тут","ты","тысяч","у","увидеть","уж","уже","улица","уметь","утро","хороший","хорошо","хотел бы","хотеть","хоть","хотя","хочешь","час","часто","часть","чаще","чего","человек","чем","чему","через","четвертый","четыре","четырнадцатый","четырнадцать","что","чтоб","чтобы","чуть","шестнадцатый","шестнадцать","шестой","шесть","эта","эти","этим","этими","этих","это","этого","этой","этом","этому","этот","эту","я","являюсь"])
stop_words.update(stopwords_from_internet_1)

# %% [markdown]
# ##### Отдельные слова (без разделения на PoS)

# %%
count_vect = CountVectorizer(stop_words=stop_words) 
bow = count_vect.fit_transform(corpus) 

print("Размер мешка без учёта стоп-слов:", bow.shape)
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:388: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['хотел'] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# Размер мешка без учёта стоп-слов: (18982, 26062)

# %%
word_list=count_vect.get_feature_names() 
count_list = bow.toarray().sum(axis=0)

# %%
x = dict(zip(word_list,count_list))
{k: v for k, v in sorted(x.items(), key=lambda item: item[1],reverse=True)}
g={k: v for k, v in sorted(x.items(), key=lambda item: item[1],reverse=True)}
result_series = pd.Series(g)

# %%
result_series[0:30]
# Out:
# казак        1823
# хутор         828
# конь          799
# лошадь        670
# дон           596
# полк          579
# красный       553
# сотня         525
# улыбаться     509
# офицер        478
# глядеть       475
# старик        468
# черный        439
# станица       398
# губа          362
# баба          347
# ветер         329
# казачий       321
# зараз         317
# фронт         313
# командир      308
# возле         298
# подымать      296
# крикнуть      295
# спина         292
# палец         282
# кровь         281
# молодой       276
# бог           272
# двор          270
# dtype: int64

# %%
result_series[0:30].values
# Out:
# array([1823,  828,  799,  670,  596,  579,  553,  525,  509,  478,  475,
#         468,  439,  398,  362,  347,  329,  321,  317,  313,  308,  298,
#         296,  295,  292,  282,  281,  276,  272,  270], dtype=int64)

# %%
list(result_series.index)
# Out:
# ['казак',
#  'хутор',
#  'конь',
#  'лошадь',
#  'дон',
#  'полк',
#  'красный',
#  'сотня',
#  'улыбаться',
#  'офицер',
#  'глядеть',
#  'старик',
#  'черный',
#  'станица',
#  'губа',
#  'баба',
#  'ветер',
#  'казачий',
#  'зараз',
#  'фронт',
#  'командир',
#  'возле',
#  'подымать',
#  'крикнуть',
#  'спина',
#  'палец',
#  'кровь',
#  'молодой',
#  'бог',
#  'двор',
#  'убивать',
#  'бросать',
#  'власть',
#  'армия',
#  'красноармеец',
#  'черт',
#  'генерал',
#  'начинать',
#  'вставать',
#  'бой',
#  'ишо',
#  'ходить',
#  'дед',
#  'словно',
#  'шинель',
#  'ладонь',
#  'солнце',
#  'вешенский',
#  'грудь',
#  'сердце',
#  'хозяин',
#  'проходить',
#  'степь',
#  'сын',
#  'зуб',
#  'дивизия',
#  'приезжать',
#  'шаг',
#  'молча',
#  'поехать',
#  'снимать',
#  'щека',
#  'входить',
#  'рот',
#  'левый',
#  'садиться',
#  'огонь',
#  'остальной',
#  'улыбка',
#  'база',
#  'седло',
#  'крыльцо',
#  'слышать',
#  'шашка',
#  'смерть',
#  'чужой',
#  'лес',
#  'пулемет',
#  'нету',
#  'винтовка',
#  'глянуть',
#  'спать',
#  'видно',
#  'молчать',
#  'толпа',
#  'бежать',
#  'серый',
#  'курень',
#  'петр',
#  'принимать',
#  'ложиться',
#  'просить',
#  'подниматься',
#  'колено',
#  'отряд',
#  'рассказывать',
#  'слеза',
#  'снег',
#  'донской',
#  'повертываться',
#  'запах',
#  'штокман',
#  'волос',
#  'ить',
#  'штаб',
#  'высокий',
#  'хлеб',
#  'собираться',
#  'ус',
#  'трава',
#  'решать',
#  'скоро',
#  'шея',
#  'большевик',
#  'находить',
#  'атаман',
#  'держать',
#  'приходиться',
#  'тихо',
#  'желтый',
#  'рубаха',
#  'узнавать',
#  'брат',
#  'вести',
#  'кинуть',
#  'небо',
#  'угол',
#  'успевать',
#  'зеленый',
#  'муж',
#  'приказывать',
#  'сотник',
#  'бить',
#  'бугор',
#  'ворота',
#  'домой',
#  'дрожать',
#  'конный',
#  'живой',
#  'нести',
#  'останавливаться',
#  'плетень',
#  'сапог',
#  'брать',
#  'бык',
#  'ухо',
#  'оставлять',
#  'видать',
#  'крик',
#  'христоня',
#  'кричать',
#  'сон',
#  'упасть',
#  'вытирать',
#  'оглядывать',
#  'получать',
#  'тело',
#  'гора',
#  'отходить',
#  'широкий',
#  'платок',
#  'батарея',
#  'войско',
#  'густой',
#  'кухня',
#  'гришка',
#  'фуражка',
#  'борода',
#  'конский',
#  'мокрый',
#  'бок',
#  'пленный',
#  'цепь',
#  'корнилов',
#  'нечего',
#  'подвода',
#  'полагать',
#  'пуля',
#  'солдат',
#  'верста',
#  'пить',
#  'двое',
#  'приказ',
#  'неделя',
#  'рукав',
#  'военный',
#  'горница',
#  'движение',
#  'ежели',
#  'повертывать',
#  'сухой',
#  'выстрел',
#  'короткий',
#  'бровь',
#  'пот',
#  'пыль',
#  'выезжать',
#  'господин',
#  'месяц',
#  'повод',
#  'поводить',
#  'правительство',
#  'правый',
#  'тишина',
#  'круг',
#  'смеяться',
#  'вздыхать',
#  'горячий',
#  'немец',
#  'переходить',
#  'указывать',
#  'бояться',
#  'всякий',
#  'подтелок',
#  'старуха',
#  'ход',
#  'лоб',
#  'небось',
#  'взвод',
#  'прямо',
#  'нос',
#  'пускать',
#  'татарский',
#  'усть',
#  'го',
#  'длинный',
#  'край',
#  'вперед',
#  'заговаривать',
#  'письмо',
#  'плеть',
#  'удар',
#  'доставать',
#  'вахмистр',
#  'встречать',
#  'забирать',
#  'мысль',
#  'оружие',
#  'площадь',
#  'погодить',
#  'позади',
#  'дюже',
#  'либо',
#  'добрый',
#  'кудинов',
#  'посылать',
#  'рысь',
#  'служба',
#  'завтра',
#  'падать',
#  'полный',
#  'приседать',
#  'синий',
#  'слух',
#  'труд',
#  'дождь',
#  'есаул',
#  'знакомый',
#  'поставлять',
#  'служить',
#  'стена',
#  'проклятый',
#  'сарай',
#  'тонкий',
#  'холодный',
#  'боль',
#  'медленно',
#  'чувство',
#  'язык',
#  'находиться',
#  'округ',
#  'сквозь',
#  'ответ',
#  'поглядеть',
#  'поле',
#  'рабочий',
#  'вскакивать',
#  'голубой',
#  'кровать',
#  'резко',
#  'ступать',
#  'искать',
#  'никак',
#  'прежний',
#  'сани',
#  'чистый',
#  'иной',
#  'сходить',
#  'ум',
#  'чувствовать',
#  'берег',
#  'вагон',
#  'радость',
#  'чей',
#  'юбка',
#  'начинаться',
#  'отступать',
#  'попадать',
#  'сват',
#  'офицерский',
#  'прижимать',
#  'речь',
#  'стремя',
#  'анна',
#  'доходить',
#  'пытаться',
#  'восстание',
#  'наступление',
#  'пахнуть',
#  'родной',
#  'войсковой',
#  'гриша',
#  'играть',
#  'михаил',
#  'порядок',
#  'предлагать',
#  'противник',
#  'ребята',
#  'слушать',
#  'стрелять',
#  'выпивать',
#  'изредка',
#  'копыто',
#  'песня',
#  'замечать',
#  'занимать',
#  'ко',
#  'услышать',
#  'батя',
#  'богатырев',
#  'отдавать',
#  'пан',
#  'скакать',
#  'снаряд',
#  'чубатый',
#  'валет',
#  'всадник',
#  'дышать',
#  'ка',
#  'кой',
#  'аникушка',
#  'гость',
#  'станция',
#  'яр',
#  'глухой',
#  'махнуть',
#  'передавать',
#  'покрывать',
#  'приносить',
#  'сюда',
#  'тронуть',
#  'тяжело',
#  'тяжелый',
#  'веселый',
#  'здоровый',
#  'квартира',
#  'команда',
#  'происходить',
#  'слыхать',
#  'быстро',
#  'воевать',
#  'девка',
#  'держаться',
#  'забывать',
#  'полковник',
#  'помогать',
#  'собирать',
#  'спешить',
#  'уезжать',
#  'хучь',
#  'бричка',
#  'кулак',
#  'лавка',
#  'обращаться',
#  'открывать',
#  'провожать',
#  'разный',
#  'розовый',
#  'шаровары',
#  'грязь',
#  'неподалеку',
#  'ох',
#  'семья',
#  'верить',
#  'вскоре',
#  'карман',
#  'крыло',
#  'крыша',
#  'патрон',
#  'поправлять',
#  'продолжать',
#  'проулок',
#  'след',
#  'смех',
#  'тоска',
#  'тянуть',
#  'бабий',
#  'вчера',
#  'детишки',
#  'каледин',
#  'каргинский',
#  'короче',
#  'мертвый',
#  'орудие',
#  'спустя',
#  'вновь',
#  'вспомнить',
#  'гнать',
#  'гутаривать',
#  'состав',
#  'атака',
#  'заставлять',
#  'коммунист',
#  'направляться',
#  'начальник',
#  'оттуда',
#  'смуглый',
#  'сто',
#  'сутки',
#  'ударять',
#  'урядник',
#  'хозяйство',
#  'капарин',
#  'попросить',
#  'проводить',
#  'выбирать',
#  'выступать',
#  'касаться',
#  'опускать',
#  'парень',
#  'пущать',
#  'раненый',
#  'соглашаться',
#  'сундук',
#  'туча',
#  'беда',
#  'висеть',
#  'густо',
#  'дух',
#  'нехай',
#  'прощать',
#  'страх',
#  'темнота',
#  'глухо',
#  'дым',
#  'закуривать',
#  'наступать',
#  'отводить',
#  'подъезжать',
#  'пулеметный',
#  'совет',
#  'тень',
#  'теплый',
#  'участок',
#  'хвост',
#  'дома',
#  'оглянуться',
#  'папаха',
#  'покидать',
#  'сзади',
#  'страшный',
#  'глубокий',
#  'дурак',
#  'евгений',
#  'железный',
#  'колесо',
#  'командование',
#  'крест',
#  'лист',
#  'положение',
#  'проговаривать',
#  'рассвет',
#  'стараться',
#  'трое',
#  'великий',
#  'вешка',
#  'впереди',
#  'враг',
#  'гул',
#  'мелкий',
#  'надевать',
#  'направление',
#  'нынче',
#  'тысяча',
#  'эх',
#  'биться',
#  'братец',
#  'зайти',
#  'здорово',
#  'калмыков',
#  'новочеркасск',
#  'оглядываться',
#  'окоп',
#  'хоперский',
#  'читать',
#  'шагать',
#  'кнут',
#  'корпус',
#  'немой',
#  'оказываться',
#  'отказываться',
#  'память',
#  'плохо',
#  'пьяный',
#  'тихий',
#  'трогать',
#  'член',
#  'закрывать',
#  'порог',
#  'прибывать',
#  'привозить',
#  'прикрывать',
#  'расстреливать',
#  'ревком',
#  'редкий',
#  'хозяйка',
#  'аль',
#  'арба',
#  'вспыхивать',
#  'горький',
#  'задыхаться',
#  'кончать',
#  'красивый',
#  'крохотный',
#  'лагутин',
#  'молоко',
#  'обнимать',
#  'переводить',
#  'плакать',
#  'сено',
#  'тянуться',
#  'бурый',
#  'дорогой',
#  'ермаков',
#  'небольшой',
#  'поглядывать',
#  'секунда',
#  'тревога',
#  'хватить',
#  'христос',
#  'шапка',
#  'бумага',
#  'внимательно',
#  'волнение',
#  'грязный',
#  'заря',
#  'конюшня',
#  'краснов',
#  'крупный',
#  'курить',
#  'момент',
#  'погон',
#  'половина',
#  'просыпаться',
#  'сажень',
#  'торопливо',
#  'широко',
#  'брехать',
#  'взводный',
#  'внимание',
#  'вызывать',
#  'высоко',
#  'жеребец',
#  'землянка',
#  'легко',
#  'огромный',
#  'повозка',
#  'пропадать',
#  'рассматривать',
#  'собака',
#  'хотеться',
#  'шепнуть',
#  'боевой',
#  'волна',
#  'двигаться',
#  'комиссар',
#  'милый',
#  'обоз',
#  'помирать',
#  'помолчать',
#  'распахнуть',
#  'расходиться',
#  'седой',
#  'сильный',
#  'стакан',
#  'тыл',
#  'благородие',
#  'дикий',
#  'еланский',
#  'кобыла',
#  'комитет',
#  'коричневый',
#  'корова',
#  'одевать',
#  'следом',
#  'слезать',
#  'спускаться',
#  'трошки',
#  'шутка',
#  'являться',
#  'батальон',
#  'вытягивать',
#  'группа',
#  'едва',
#  'жизень',
#  'злой',
#  'испытывать',
#  'мишатка',
#  'наган',
#  'направлять',
#  'немецкий',
#  'носить',
#  'острый',
#  'повстанческий',
#  'подавать',
#  'показываться',
#  'приводить',
#  'простой',
#  'сад',
#  'бывший',
#  'взяться',
#  'донский',
#  'дрогнуть',
#  'жалко',
#  'захватить',
#  'ихний',
#  'ишь',
#  'куст',
#  'мелеховский',
#  'осторожно',
#  'плохой',
#  'подтелков',
#  'похожий',
#  'председатель',
#  'рота',
#  'рубить',
#  'сводить',
#  'слава',
#  'хата',
#  'хватать',
#  'число',
#  'взглядывать',
#  'влажный',
#  'воздух',
#  'карта',
#  'легкий',
#  'локоть',
#  'мундир',
#  'полдень',
#  'полушубок',
#  'протягивать',
#  'темный',
#  'фланг',
#  'калитка',
#  'кожа',
#  'линия',
#  'рыжий',
#  'сообщать',
#  'строй',
#  'схватывать',
#  'чернеть',
#  'шептать',
#  'шлях',
#  'бывать',
#  'горло',
#  'косой',
#  'осень',
#  'пехота',
#  'печь',
#  'потерять',
#  'появляться',
#  'разговаривать',
#  'спешиваться',
#  'сукин',
#  'твердо',
#  'царь',
#  'штык',
#  'гимнастерка',
#  'господи',
#  'грех',
#  'дочь',
#  'область',
#  'окружать',
#  'отправлять',
#  'ощущать',
#  'передний',
#  'петроград',
#  'повстанец',
#  'показывать',
#  'ради',
#  'сенцы',
#  'близкий',
#  'воротник',
#  'вроде',
#  'жадно',
#  'лишний',
#  'навстречу',
#  'нижний',
#  'ординарец',
#  'слегка',
#  'целый',
#  'чумак',
#  'ах',
#  'вдоль',
#  'возвращаться',
#  'германский',
#  'кормить',
#  'натягивать',
#  'перебивать',
#  'поддерживать',
#  'прийти',
#  'сотенный',
#  'удерживать',
#  'черта',
#  'баркас',
#  'вслед',
#  'выдавать',
#  'гумно',
#  'добро',
#  'ежли',
#  'защитный',
#  'зима',
#  'испуганно',
#  'конница',
#  'красногвардеец',
#  'крепко',
#  'мешок',
#  'накинуть',
#  'очередь',
#  'прижиматься',
#  'припадать',
#  'распоряжение',
#  'ремень',
#  'сволочь',
#  'сдавать',
#  'среди',
#  'страшно',
#  'суд',
#  'чин',
#  'юг',
#  'богатый',
#  'весна',
#  'виднеться',
#  'восток',
#  'голый',
#  'гореть',
#  'живот',
#  'задний',
#  'здравствовать',
#  'казачество',
#  'камень',
#  'маманя',
#  'намет',
#  'останавливать',
#  'плотно',
#  'придерживать',
#  'проведывать',
#  'служивый',
#  'сорок',
#  'сосед',
#  'твердый',
#  'хуторской',
#  'банда',
#  'большинство',
#  'вполголоса',
#  'вспоминать',
#  'запрягать',
#  'некогда',
#  'неожиданно',
#  'отрывать',
#  'революционный',
#  'ростов',
#  'сбивать',
#  'свежий',
#  'середина',
#  'церковь',
#  'шамиль',
#  'блестеть',
#  'воля',
#  'кошева',
#  'ночевать',
#  'пара',
#  'поймать',
#  'разъезд',
#  'рана',
#  'сознание',
#  'тополь',
#  'эй',
#  'амбар',
#  'везти',
#  'догнать',
#  'казанский',
#  'кривошлыков',
#  'курган',
#  'любовь',
#  'низкий',
#  'отдыхать',
#  'побивать',
#  'ругаться',
#  'скрываться',
#  'сунуть',
#  'тридцать',
#  'эскадрон',
#  'воспоминание',
#  'встречаться',
#  'вынимать',
#  'дальний',
#  'добровольческий',
#  'желать',
#  'кинуться',
#  'кончаться',
#  'круглый',
#  'местечко',
#  'миг',
#  'мол',
#  'наливать',
#  'ноздря',
#  'поздно',
#  'попадаться',
#  'попов',
#  'походный',
#  'свертывать',
#  'тотчас',
#  'фигура',
#  'хорунжий',
#  'шевелить',
#  'шуметь',
#  'бледный',
#  'вожжа',
#  'выпускать',
#  'досада',
#  'запад',
#  'лед',
#  'общий',
#  'отношение',
#  'песок',
#  'пеший',
#  'революция',
#  'умирать',
#  'шепотом',
#  'выскочить',
#  'горе',
#  'гребень',
#  'громко',
#  'ездить',
#  'жевать',
#  'засмеяться',
#  'звучать',
#  'злоба',
#  'крючок',
#  'мужик',
#  'нужда',
#  'одеваться',
#  'орудийный',
#  'отзываться',
#  'подол',
#  'поклон',
#  'полчаса',
#  'поскакать',
#  'прислушиваться',
#  'разбивать',
#  'самогон',
#  'сбоку',
#  'следующий',
#  'слышно',
#  'соль',
#  'спокойно',
#  'станичный',
#  'табак',
#  'тронуться',
#  'цвет',
#  'цигарка',
#  'английский',
#  'босой',
#  'верно',
#  'верхний',
#  'догадываться',
#  'зло',
#  'мельница',
#  'мера',
#  'мост',
#  'охватывать',
#  'поговорить',
#  'позиция',
#  'потный',
#  'поэтому',
#  'пулеметчик',
#  'рад',
#  'расти',
#  'рыба',
#  'сени',
#  'сиять',
#  'степной',
#  'угадывать',
#  'федот',
#  'атаманский',
#  'бинокль',
#  'вначале',
#  'водка',
#  'глупый',
#  'господь',
#  'граница',
#  'добираться',
#  'заглядывать',
#  'закричать',
#  'заявлять',
#  'звук',
#  'иначе',
#  'командовать',
#  'круто',
#  'кусок',
#  'мигулинский',
#  'население',
#  'переправляться',
#  'плыть',
#  'пожилой',
#  'полка',
#  'понести',
#  'посмеиваться',
#  'почувствовать',
#  'проживать',
#  'разбудить',
#  'редко',
#  'румянец',
#  'сизый',
#  'стискивать',
#  'строго',
#  'фраза',
#  'целовать',
#  'ажник',
#  'балка',
#  'восклицать',
#  'выход',
#  'зачинать',
#  'издали',
#  'коса',
#  'косить',
#  'красноармейский',
#  'людской',
#  'морщиться',
#  'норовить',
#  'ой',
#  'отбивать',
#  'партия',
#  'песчаный',
#  'печка',
#  'поручик',
#  'потянуть',
#  'привязывать',
#  'прошлый',
#  'разводить',
#  'слагать',
#  'соседний',
#  'спасать',
#  'уснуть',
#  'чисто',
#  'чулок',
#  'шагнуть',
#  'больной',
#  'встреча',
#  'выбегать',
#  'выдерживать',
#  'заплакать',
#  'зря',
#  'мягко',
#  'настроение',
#  'обратно',
#  'ожидать',
#  'опираться',
#  'побледнеть',
#  'помощь',
#  'присылать',
#  'пустой',
#  'раздеваться',
#  'рвать',
#  'решительно',
#  'складка',
#  'совещание',
#  'срываться',
#  'старший',
#  'течение',
#  'течь',
#  'трудно',
#  'туго',
#  'узкий',
#  'уничтожать',
#  'шум',
#  'бригада',
#  'вырывать',
#  'залп',
#  'застава',
#  'золотой',
#  'имение',
#  'имущество',
#  'казачок',
#  'каменская',
#  'колонна',
#  'крайний',
#  'лог',
#  'москва',
#  ...]

# %%
plt.figure(figsize=(15,8))
sns.barplot(x=result_series[0:20].index, y=result_series[0:20].values,color='blue')
plt.title("Частотность слов")
plt.show()

# %% [markdown]
# ##### Биграммы

# %%
# %%time
count_vect = CountVectorizer(ngram_range=(2, 2),stop_words=stop_words)
#n_gramm = count_vect.fit_transform(corpus)
bow = count_vect.fit_transform(corpus) 
print("Размер мешка без учёта стоп-слов:", bow.shape)
#print(word_list)
#print(count_list)
word_list=count_vect.get_feature_names() 
count_list = bow.toarray().sum(axis=0)
#print(word_list)
#print(count_list)
#print(dict(zip(word_list,count_list)))
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:388: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['хотел'] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# Размер мешка без учёта стоп-слов: (18982, 185263)
# Wall time: 28 s

# %%
x = dict(zip(word_list,count_list))
{k: v for k, v in sorted(x.items(), key=lambda item: item[1],reverse=True)}
big={k: v for k, v in sorted(x.items(), key=lambda item: item[1],reverse=True)}
result_series_bigram = pd.Series(big)
#result_series_bigram

# %%
result_series_bigram[0:40]
# Out:
# усть хоперский             51
# красный армия              49
# сукин сын                  49
# командир полк              47
# командир сотня             46
# добровольческий армия      41
# слава бог                  40
# донской армия              35
# войско донской             32
# тихий дон                  32
# военный революционный      30
# го полк                    30
# прижимать грудь            30
# ради христос               30
# усть медведицкий           30
# революционный комитет      28
# временный правительство    26
# войсковой старшина         25
# навес сарай                25
# хутор татарский            25
# казачий полк               24
# начальник штаб             24
# стискивать зуб             24
# живой здоровый             23
# молодой казак              23
# конский копыто             22
# походный порядок           22
# штаб дивизия               22
# взводный офицер            21
# сердобский полк            21
# войсковой правительство    20
# господин офицер            20
# мокрый пот                 20
# правый фланг               20
# царство небесный           20
# атаманский полк            19
# левый фланг                19
# сотня казак                19
# спасать христос            19
# усть медведица             19
# dtype: int64

# %%
plt.figure(figsize=(15,8))
sns.barplot(x=result_series_bigram[0:20].index, y=result_series_bigram[0:20].values,color='blue')
plt.title("Частотность биграмм")
plt.show()

# %% [markdown]
# #####  Триграммы

# %%
count_vect = CountVectorizer(ngram_range=(3, 3),stop_words=stop_words) 
bow = count_vect.fit_transform(corpus) 
print("Размер мешка без учёта стоп-слов:", bow.shape)
word_list=count_vect.get_feature_names() 
count_list = bow.toarray().sum(axis=0)
#print(dict(zip(word_list,count_list)))
x = dict(zip(word_list,count_list))
{k: v for k, v in sorted(x.items(), key=lambda item: item[1],reverse=True)}
trig={k: v for k, v in sorted(x.items(), key=lambda item: item[1],reverse=True)}
result_series_trig = pd.Series(trig)
#result_series_trig
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:388: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['хотел'] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# Размер мешка без учёта стоп-слов: (18982, 188925)

# %%
result_series_trig[0:15]
# Out:
# военный революционный комитет    28
# всевеликий войско донской        12
# военный полевой суд              11
# лейб гвардия атаманский          11
# гвардия атаманский полк           9
# донской казачий полк              8
# усть медведицкий округ            8
# усть хоперский станица            8
# безрукий алешка шамиль            7
# казачий военный революционный     7
# совет союз казачий                7
# союз казачий войско               7
# 12 го полк                        6
# 44 го полк                        6
# запах конский пот                 6
# dtype: int64

# %%
plt.figure(figsize=(15,8))
sns.barplot(x=result_series_trig[0:15].index, y=result_series_trig[0:15].values,color='blue')
plt.title("Частотность триграмм")
plt.show()

# %% [markdown]
# ##### Четыреграммы

# %%
count_vect = CountVectorizer(ngram_range=(4, 4),stop_words=stop_words) 
bow = count_vect.fit_transform(corpus) 
print("Размер мешка без учёта стоп-слов:", bow.shape)
word_list=count_vect.get_feature_names() 
count_list = bow.toarray().sum(axis=0)
x = dict(zip(word_list,count_list))
{k: v for k, v in sorted(x.items(), key=lambda item: item[1],reverse=True)}
fourg={k: v for k, v in sorted(x.items(), key=lambda item: item[1],reverse=True)}
result_series_fourg = pd.Series(fourg)
result_series_fourg
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:388: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['хотел'] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# Размер мешка без учёта стоп-слов: (18982, 175944)
# лейб гвардия атаманский полк                9
# казачий военный революционный комитет       7
# совет союз казачий войско                   7
# делегат 44 го полк                          4
# командующий донской армия генерал           4
#                                            ..
# ящик патрон снаряд направлять               1
# ящик покурить утыкаться сено                1
# ящик пособлять лошадь подъем                1
# ящик преимущественно казак бывший           1
# ящик проезжать всматриваться привязывать    1
# Length: 175944, dtype: int64

# %%
plt.figure(figsize=(15,8))
sns.barplot(x=result_series_fourg[0:15].index, y=result_series_fourg[0:15].values,color='blue')
plt.title("Частотность четыреграмм")
plt.show()

# %% [markdown]
# #### Entities (географические регионы)

# %% [markdown]
# В данном случае придется использовать необработанный текст, так как сущности плохо находятся, если они не в верхнем регистре.

# %%
# %%time
#doc = docx.Document("C:\\Users\\Admin\\OneDrive\\PET Projects (06-12)\\Тихий Дон\\Тихий_дон отрывок.docx")
doc = docx.Document("C:\\Users\\Admin\\OneDrive\\PET Projects (06-12)\\Тихий Дон\\Tihij_don_full.docx")
# Out:
# Wall time: 169 ms

# %%
all_paras = doc.paragraphs
len(all_paras)
fullText = []
for para in doc.paragraphs:
    fullText.append(para.text)
df1=pd.Series(fullText)

# %% [markdown]
# <b>Обработаем дефект импорта датасета</b>

# %%
df1=df1.replace('\xa0', ' ')

# %%
corpus = df1.values.astype('U')

# %%
#Функция для очистки текста
def clear_text(text):
    return " ".join(re.sub(r'[^a-zA-Zа-яА-я0-9 ]', ' ', text).split())  

#Функция для лемматизации токена
def lemmatize(text): 
    return "".join(m.lemmatize(text))

# %%
#Проверим работу библиотеки для поиска локаций'
text='Сергей приехал в Берлин, затем купил фруктовый сок. Татьяна позвонила Антону Павловичу.В Москве было холодно'
doc=nlp(text)
location=set()
for ent in doc.ents:
    if ent.label_ =='LOC':
        location.add(ent.lemma_.capitalize())
location
# Out:
# {'Берлин', 'Москва'}

# %%
# %%time
location=list()
for i in tqdm(range(len(corpus))):
    doc=nlp(str(corpus[i]))
    for ent in doc.ents:
        if ent.label_ =='LOC':
            location.append((ent.lemma_.capitalize()))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 20112/20112 [03:48<00:00, 88.06it/s]
# Wall time: 3min 48s

# %%
for i in tqdm(range(len(location))):
    location[i]=(lemmatize(location[i])).capitalize()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 3644/3644 [49:36<00:00,  1.22it/s]

# %%
for i in tqdm(range(len(location))):
    location[i]=(clear_text(location[i]))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 3644/3644 [00:00<00:00, 456703.63it/s]

# %%
location_dict=Counter(location)
{k: v for k, v in sorted(location_dict.items(), key=lambda item: item[1],reverse=True)}
# Out:
# {'Григорий': 228,
#  'Дон': 227,
#  'Вешенский': 134,
#  'Ильич': 113,
#  'Россия': 85,
#  'Новочеркасск': 68,
#  'Ильинична': 62,
#  'Вешка': 62,
#  'Каргинский': 56,
#  'Петроград': 51,
#  'Аксинья': 43,
#  'Москва': 42,
#  'Татарский': 39,
#  'Ростов': 37,
#  'Кубань': 35,
#  'Усть хоперский': 32,
#  'Казанский': 31,
#  'Ягодный': 27,
#  'Каменская': 24,
#  'Украина': 23,
#  'Воронеж': 22,
#  'Миллерово': 22,
#  'Еланский': 20,
#  'Усть медведица': 19,
#  'Чир': 18,
#  'Ставка': 18,
#  'Дуняшка': 18,
#  'Прохор': 18,
#  'Донский область': 17,
#  'Германия': 17,
#  'Советский власть': 17,
#  'Советский': 17,
#  'Усть медведицкий': 15,
#  'Хоперский округ': 15,
#  'Наталья': 14,
#  'Хопер': 13,
#  'Польша': 13,
#  'Букановский': 13,
#  'Верхнедонский округ': 13,
#  'Боковский': 13,
#  'Донец': 13,
#  'Дарья': 12,
#  'Луганск': 11,
#  'Царицын': 11,
#  'Запад': 10,
#  'Авдеич': 10,
#  'Базок': 10,
#  'Вешенский станица': 10,
#  'Еланский станица': 10,
#  'Глубокий': 10,
#  'Краснокутский': 10,
#  'Христоня': 9,
#  'Франция': 9,
#  'Румыния': 9,
#  'Крым': 9,
#  'Таганрог': 9,
#  'Новороссийск': 9,
#  'Аксиньин': 8,
#  'Пантелей прокофиевич': 8,
#  'Мигулинская': 8,
#  'Усть медведицкий округ': 8,
#  'Пруссия': 8,
#  'Кумылженский': 8,
#  'Кавказ': 8,
#  'Слащевский': 8,
#  'Митька': 7,
#  'Мишка': 7,
#  'Донский': 7,
#  'Донецкий округ': 7,
#  'Краснокутский станица': 7,
#  'Воронежский губерния': 7,
#  'Лихой': 7,
#  'Екатеринодар': 7,
#  'Мигулинский': 7,
#  'Рост': 7,
#  'Северный фронт': 7,
#  'Климовка': 7,
#  'Восточный пруссия': 6,
#  'Аникушка': 6,
#  'Нижний яблоновский': 6,
#  'Читать': 6,
#  'Саратовский губерния': 6,
#  'Стоход': 6,
#  'Сибирь': 6,
#  'Могилев': 6,
#  'Питер': 6,
#  'Кошевой': 6,
#  'Усть хопер': 6,
#  'Всевеликий войско': 6,
#  'Гетманский шлях': 6,
#  'Мешковский': 6,
#  'Гришка': 5,
#  'Дубровка': 5,
#  'Петербург': 5,
#  'Татарск': 5,
#  'Черный': 5,
#  'Доноситься': 5,
#  'Не е ет': 5,
#  'Петр': 5,
#  'Листницкий': 5,
#  'Киев': 5,
#  'Донщина': 5,
#  'Галиция': 5,
#  'Бестолковый': 5,
#  'Каменка струмилово': 5,
#  'Дивизия': 5,
#  'Мишка кошевой': 5,
#  'Офицерский союз': 5,
#  'Земля': 5,
#  'Псков': 5,
#  'Нарва': 5,
#  'Хоперский': 5,
#  'Войсковой круг': 5,
#  'Сиверс': 5,
#  'Волга': 5,
#  'Шумилинский': 5,
#  'Боковский станица': 5,
#  'Каргин': 5,
#  'Казанский станица': 5,
#  'Усть хоперский станица': 5,
#  'Шумилинская': 5,
#  'Кривский': 5,
#  'Астахов': 5,
#  'Степан': 4,
#  'Баланда': 4,
#  'Атаманский': 4,
#  'Англия': 4,
#  'Левада': 4,
#  'Чертково': 4,
#  'Лиски': 4,
#  'Карпаты': 4,
#  'Березняга': 4,
#  'Юго западный фронт': 4,
#  'Гороховка': 4,
#  'Обдонской гора': 4,
#  'Двинск': 4,
#  'Каледин': 4,
#  'Корнилов': 4,
#  'Терек': 4,
#  'Дно': 4,
#  'Быхов': 4,
#  'Донской': 4,
#  'Советский россия': 4,
#  'Круг': 4,
#  'Русь': 4,
#  'Мишатка': 4,
#  'Алферов': 4,
#  'Астрахань': 4,
#  'Поворино': 4,
#  'Усть белокалитвенский': 4,
#  'Алексеевский станица': 4,
#  'Чистяковка': 4,
#  'Тамбов': 4,
#  'Горбатовский': 4,
#  'Мишаток': 4,
#  'Рубежный': 4,
#  'Церква': 3,
#  'Томилин': 3,
#  'Красный яр': 3,
#  'Христонин': 3,
#  'Урюпинский': 3,
#  'Грузия': 3,
#  'Варшава': 3,
#  'Атепин цаца': 3,
#  'Ястреб': 3,
#  'Азовский море': 3,
#  'Маньково': 3,
#  'Ольшанский': 3,
#  'Радзивилловый': 3,
#  'Штокман': 3,
#  'Королевка': 3,
#  'Лешнюв': 3,
#  'Тверской': 3,
#  'Черкеска': 3,
#  'Незвиска': 3,
#  'Свинюха': 3,
#  'Млечный путь': 3,
#  'Аникушкин': 3,
#  'Глазуновский': 3,
#  'Днепр': 3,
#  'Первый': 3,
#  'Четвертый полка': 3,
#  'Букановский станица': 3,
#  'Лагутин': 3,
#  'Зимний дворец': 3,
#  'Павловск': 3,
#  'Сальский округ': 3,
#  'Великокняжеский': 3,
#  'Симбирский губерния': 3,
#  'Смоленск': 3,
#  'Буковина': 3,
#  'Тихорецкий': 3,
#  'Себряковый': 3,
#  'Геворкянц': 3,
#  'Богаевский': 3,
#  'Черкасск': 3,
#  'Каменка': 3,
#  'Мигулинский станица': 3,
#  'Федосеевский': 3,
#  'Сетраково': 3,
#  'Сетраков': 3,
#  'Каргинский станица': 3,
#  'Алексеевский': 3,
#  'Двенадцатый': 3,
#  'Зимова станица': 3,
#  'Северный кавказ': 3,
#  'Доно кавказский союз': 3,
#  'Кореновский': 3,
#  'Топкий балка': 3,
#  'Лондон': 3,
#  'Сингин': 3,
#  'Мишкино': 3,
#  'Архиповка': 3,
#  'Чира': 3,
#  'Усть хоперский юрта': 3,
#  'Крутовский': 3,
#  'Бахмуткин': 3,
#  'Бобровский': 3,
#  'Медведица': 3,
#  'Маныч': 3,
#  'Балашов': 3,
#  'Новохоперск': 3,
#  'Капарина': 3,
#  'Мавр': 2,
#  'Персиановка': 2,
#  'Мелехов': 2,
#  'Василиса': 2,
#  'Кавказский гора': 2,
#  'Азы': 2,
#  'Чигонака': 2,
#  'Нижний': 2,
#  'Давыдка': 2,
#  'Батайск': 2,
#  'Елизавета': 2,
#  'Митькин': 2,
#  'Панкратий': 2,
#  'Федот': 2,
#  'Красный': 2,
#  'Санкт петербург': 2,
#  'Тепикинский станица': 2,
#  'Каменская станица': 2,
#  'Азовский': 2,
#  'Тоска': 2,
#  'Франя': 2,
#  'Гайтан': 2,
#  'Вильно': 2,
#  'Пеликалий': 2,
#  'Цуцкан': 2,
#  'Брод': 2,
#  'Сто': 2,
#  'Чубатый': 2,
#  'Тула': 2,
#  'Чембарский': 2,
#  'Бугульминский': 2,
#  'Павлоградский': 2,
#  'Валет': 2,
#  'Емельян': 2,
#  'Западный двина': 2,
#  'Алешка шамиль': 2,
#  'Пятьдесят': 2,
#  'Харьков': 2,
#  'Невский': 2,
#  'Совдеп': 2,
#  'Царский село': 2,
#  'Урал': 2,
#  'Уссури': 2,
#  'Горелый': 2,
#  'Везенберг': 2,
#  'Сомрино': 2,
#  'Вырица': 2,
#  'Дворцовый площадь': 2,
#  'Федосеевский станица': 2,
#  'Каргинский бугор': 2,
#  'Климовский': 2,
#  'Донецкий бассейн': 2,
#  'Керенский': 2,
#  'Тюковновский': 2,
#  'Казачий': 2,
#  'Филонов': 2,
#  'Кривянский': 2,
#  'Анна': 2,
#  'Совет': 2,
#  'Босс': 2,
#  'Каменский': 2,
#  'Ольховый рог': 2,
#  'Кашары': 2,
#  'Сулин': 2,
#  'Соборный площадь': 2,
#  'Гниловский станица': 2,
#  'Ольгинский': 2,
#  'Мелиховский': 2,
#  'Михайловский': 2,
#  'Мишкин': 2,
#  'Марья': 2,
#  'Персия': 2,
#  'Албания': 2,
#  'Европа': 2,
#  'Мигулин': 2,
#  'Песчаный курган': 2,
#  'Бунчук': 2,
#  'Белый калитва': 2,
#  'Скуришенской': 2,
#  'Михайловка': 2,
#  'Луганский': 2,
#  'Иловлинский': 2,
#  'Берлин': 2,
#  'Старобельск': 2,
#  'Ключ': 2,
#  'Арженовский': 2,
#  'Войско': 2,
#  'Таганрогский округ': 2,
#  'Германский империя': 2,
#  'Париж': 2,
#  'Филоновый': 2,
#  'Согласие': 2,
#  'Салоники': 2,
#  'Львов': 2,
#  'Фомин': 2,
#  'Обдонский гора': 2,
#  'Большой громкий': 2,
#  'Бутурлиновка': 2,
#  'Чернышевский': 2,
#  'Антип': 2,
#  'Обдонья': 2,
#  'Евангелие': 2,
#  'Пантелей': 2,
#  'Семеновский': 2,
#  'Чукарин': 2,
#  'Чукарина': 2,
#  'Латышевский': 2,
#  'Вежа': 2,
#  'Дударевский': 2,
#  'Морозовский': 2,
#  'Лиховид': 2,
#  'Обдонь': 2,
#  'Вороновский': 2,
#  'Калач': 2,
#  'Южный фронт': 2,
#  'Макеевка': 2,
#  'Юг россия': 2,
#  'Вустя хопер': 2,
#  'Еринский': 2,
#  'Громкий': 2,
#  'Калмыцкий брод': 2,
#  'Алешкин': 2,
#  'Елань': 2,
#  'Искать': 2,
#  'Евлантьевский': 2,
#  'Полюшка': 2,
#  'Британия': 2,
#  'Андрониха': 2,
#  'Сахар': 2,
#  'Тишанская': 2,
#  'Плыть': 2,
#  'Курить': 2,
#  'Латышев': 2,
#  'Христан': 2,
#  'Вешенский григорий': 2,
#  'Новый михайловский': 2,
#  'Тоннельный': 2,
#  'Красный армия': 2,
#  'Первый конный': 2,
#  'Богучарский уезд': 2,
#  'Верхний дон': 2,
#  'Нижний кривский': 2,
#  'Туретчина': 1,
#  'Мавра': 1,
#  'Прокофьев шаровары': 1,
#  'Прокофий': 1,
#  'Люшня': 1,
#  'Горбоносый': 1,
#  'Турок': 1,
#  'Безмен': 1,
#  'Митькин зуб': 1,
#  'Воровской': 1,
#  'Нету': 1,
#  'Костыль': 1,
#  'Марфушка дурочка женя': 1,
#  'Гниловский': 1,
#  'Дроздиха': 1,
#  'Гришка медведь': 1,
#  'Столыпин': 1,
#  'Гришка пожар': 1,
#  'Гришкин чирик': 1,
#  'Пантелей турку': 1,
#  'Татаровской курган': 1,
#  'Усть медведицкий монастырь': 1,
#  'Сват': 1,
#  'Гурко': 1,
#  'Геть баба': 1,
#  'Гетьково': 1,
#  'Наперегонки': 1,
#  'Гетька': 1,
#  'Извинять': 1,
#  'Благословлять': 1,
#  'Наш край': 1,
#  'Челенджийский': 1,
#  'Баклановец молодец': 1,
#  'Чигонацкий станица': 1,
#  'Сережка шибать': 1,
#  'Фроловка': 1,
#  'Тимофей': 1,
#  'Семенова пристань': 1,
#  'Никита': 1,
#  'Емельян кучер': 1,
#  'Гришенька': 1,
#  'Юго восточный железнодорожный мастерская': 1,
#  'Цыганев': 1,
#  'Бабий ендова': 1,
#  'Хутор': 1,
#  'Белый пышный убор': 1,
#  'Громковский хутор': 1,
#  'Луна': 1,
#  'Гремячий': 1,
#  'Страм': 1,
#  'Черный лес': 1,
#  'Давыдкой': 1,
#  'Миллеровский': 1,
#  'Лодзь': 1,
#  'Псалтырь': 1,
#  'Гетько': 1,
#  'Лужица': 1,
#  'Степаново': 1,
#  'Сашка': 1,
#  'Поспешать': 1,
#  'Гриша': 1,
#  'Петров': 1,
#  'Чукаринский': 1,
#  'Восток': 1,
#  'Обдонье': 1,
#  'Маньково калитвенский слобода': 1,
#  'Митякинский станица': 1,
#  'Ровно': 1,
#  'Владиславка': 1,
#  'Заборонить': 1,
#  'Кустень': 1,
#  'Верба': 1,
#  'Горовищук': 1,
#  'Берестечко': 1,
#  'Телега': 1,
#  'Манила': 1,
#  'Полковник': 1,
#  'Она': 1,
#  'Белый горючий': 1,
#  'Буян': 1,
#  'Огхо хо ха ха': 1,
#  'Далекий край': 1,
#  'Лапин': 1,
#  'Торжок': 1,
#  'Александровск': 1,
#  'Побегем': 1,
#  'Крючок': 1,
#  'Райброд': 1,
#  'Семипалатинск': 1,
#  'Сокольник': 1,
#  'Садовый триумфальный': 1,
#  'Татьянин муженек': 1,
#  'Москва река': 1,
#  'Книжка': 1,
#  'Воробьев гора': 1,
#  'Дмитровка': 1,
#  'Константиновский станица': 1,
#  'Тышвич': 1,
#  'Кобылино': 1,
#  'Станиславчик': 1,
#  'Балтика': 1,
#  'Гороша': 1,
#  'Ставинцкий': 1,
#  'Ивановка': 1,
#  'Крышовинский': 1,
#  'Березняг': 1,
#  'Кенисберг': 1,
#  'Стырь': 1,
#  'Ловишчей': 1,
#  'Ловишчами': 1,
#  'Ближний лес': 1,
#  'Купалка австрийский гаубица': 1,
#  'Ростов на дон': 1,
#  'Гочкис': 1,
#  'Бергман': 1,
#  'Виккерс': 1,
#  'Австрия': 1,
#  'Кушать': 1,
#  'Аксиньиный платье': 1,
#  'Пехота': 1,
#  'Утираться': 1,
#  'Григорьева гимнастерка': 1,
#  'Каменка струмилов': 1,
#  'Зарайск': 1,
#  'Шевелить': 1,
#  'Слышать': 1,
#  'Владимирский губерния': 1,
#  'Косой': 1,
#  'Верберг': 1,
#  'Черниговский губерния': 1,
#  'Дуня': 1,
#  'Врублевский': 1,
#  'Житомир': 1,
#  'Листницкий глаз': 1,
#  'Женева': 1,
#  'Подголосок': 1,
#  'Владимиро волынский': 1,
#  'Ковельский': 1,
#  'Сокаль': 1,
#  'Рудка меринский': 1,
#  'Малый порек': 1,
#  'Триста': 1,
#  'Че ло век': 1,
#  'Чудила а а': 1,
#  'Изуродовать': 1,
#  'Венгровский': 1,
#  'Купреяновна': 1,
#  'Есаул': 1,
#  'Доходить': 1,
#  'Ольховчик': 1,
#  'Равый русский': 1,
#  'Луцк': 1,
#  'Львов григорий': 1,
#  'Буг': 1,
#  'Чубатый глаз': 1,
#  'Рынвич': 1,
#  'Трансильванский': 1,
#  'Дашка': 1,
#  'Черный яр': 1,
#  'Кувински': 1,
#  'Мировой': 1,
#  'Донецк': 1,
#  'Каменская григорий': 1,
#  'Дурной': 1,
#  'Волго камский банк': 1,
#  'Завар': 1,
#  'Минск': 1,
#  'Разгон': 1,
#  'Грязнов казак': 1,
#  'Баку': 1,
#  'Рубежина': 1,
#  'Атаманский полка': 1,
#  'Рига': 1,
#  'Петроград район': 1,
#  'Четвертый': 1,
#  'Серебряков': 1,
#  'Лагутина': 1,
#  'Листницкий покрывать': 1,
#  'Эрдель': 1,
#  'Московский нарвский район': 1,
#  'Невель': 1,
#  'Туземный дивизия': 1,
#  'Средний европа': 1,
#  'Северный': 1,
#  'Западный фронт': 1,
#  'Государственный': 1,
#  'Мусин пушкин': 1,
#  'Чернышевский станица': 1,
#  'Турилин': 1,
#  'Ингуш': 1,
#  'Крымов': 1,
#  'Афганистан': 1,
#  'Ямбург': 1,
#  'Гатчина': 1,
#  'Чудово': 1,
#  'Гдов': 1,
#  'Новгород': 1,
#  'Ингушский': 1,
#  'Черкесский полка': 1,
#  'Уссурийский': 1,
#  'Туземный': 1,
#  'Петроградский округ': 1,
#  'Гачка': 1,
#  'Оредеж': 1,
#  'Луг': 1,
#  'Местечко': 1,
#  'Мотать': 1,
#  'Ленин': 1,
#  'Забайкалье': 1,
#  'Амур': 1,
#  'Казань': 1,
#  'До ло о ой': 1,
#  'Лукомский': 1,
#  'Романовский': 1,
#  'Бердичев': 1,
#  'Искать свищ': 1,
#  'Туркестан': 1,
#  'Ваш': 1,
#  'Орша': 1,
#  'Жлобин': 1,
#  'Гомель': 1,
#  'Терский': 1,
#  'Кусонский': 1,
#  'Эргардт': 1,
#  'Ховинеска': 1,
#  'Голшская долина': 1,
#  'Америка': 1,
#  'Кременчуг': 1,
#  'Екатеринослав': 1,
#  'Синельников': 1,
#  'Чаплин': 1,
#  'Багряно': 1,
#  'Дубовенький': 1,
#  'Прикарпатье': 1,
#  'Гундоровский станица': 1,
#  'Великороссия': 1,
#  'Снегирев': 1,
#  'Усть калиновский': 1,
#  'Еланский грань': 1,
#  'Верхний': 1,
#  'Нижний крутовский': 1,
#  'Россия матушка': 1,
#  'Марков': 1,
#  'Чертков': 1,
#  'Макеевский район': 1,
#  'Дон туча': 1,
#  'Новочеркасск облако': 1,
#  'Парамоновский рудник': 1,
#  'Московский улица': 1,
#  'Конопина': 1,
#  'Нахичевань': 1,
#  'Екатеринославщина': 1,
#  'Юнкер': 1,
#  'Приц е быть': 1,
#  'Сугрев': 1,
#  'Дубно': 1,
#  'Каледин душить': 1,
#  'Верный а а': 1,
#  'Смольный': 1,
#  'Каменская казак': 1,
#  'Атаманский полк': 1,
#  'Подтелков': 1,
#  'Мельников': 1,
#  'Горнозаводский район': 1,
#  'Донской край': 1,
#  'Донский край': 1,
#  'М богаевский старшина': 1,
#  'Зверев': 1,
#  'Северный донец': 1,
#  'Изварин': 1,
#  'Лебяжий вешенский станица': 1,
#  'Луганский станица': 1,
#  'Горловский район': 1,
#  'Миллерский': 1,
#  'Це е епь': 1,
#  'Трансильванский гора': 1,
#  'Терновский': 1,
#  'Каменская то': 1,
#  'Поповка': 1,
#  'Грачев': 1,
#  'Ясеновка': 1,
#  'Анютка': 1,
#  'Надевать': 1,
#  'Хлев': 1,
#  'Новочеркасский': 1,
#  'Малый громченок': 1,
#  'Курва': 1,
#  'Российский советский республика': 1,
#  'Неклиновка': 1,
#  'Амвросиевка': 1,
#  'Богаевский почва': 1,
#  'Тацин': 1,
#  'Пятихатка': 1,
#  'Назаров': 1,
#  'Аксай': 1,
#  'Суворовский фанагорийский гренадерский полка': 1,
#  'Голгофа': 1,
#  'Листницкий поручик': 1,
#  'Мечетинский': 1,
#  'Старый ивановский': 1,
#  'Шахтный': 1,
#  'Константиновский': 1,
#  'Бессергеневский': 1,
#  'Абрамсон': 1,
#  'Зверево': 1,
#  'Большой садовый': 1,
#  'Шептуховка': 1,
#  'Стожар': 1,
#  'Верхнедонский': 1,
#  'Верхнедонской округ': 1,
#  'Пономаревский': 1,
#  'Матвей': 1,
#  'Дымок': 1,
#  'Обливый': 1,
#  'Гусыно лиховидовский': 1,
#  'Дураццо': 1,
#  'Италия': 1,
#  'Испания': 1,
#  'Пенза': 1,
#  'Мигулинский нечего': 1,
#  'Максимка': 1,
#  'Максимкин': 1,
#  'Самара': 1,
#  'Аннин порыв': 1,
#  'Кривошлыков': 1,
#  'Игнат': 1,
#  'Белокалитвенский район': 1,
#  'Наголинский волость': 1,
#  'Рубашкино': 1,
#  'Калашников': 1,
#  'Поляково наголинский волость': 1,
#  'Данило': 1,
#  'Коротков': 1,
#  'Милютинский станица': 1,
#  'Милютинский': 1,
#  'Усть быстрянская': 1,
#  'Раздорский': 1,
#  'Новый земцева': 1,
#  'Пономарев': 1,
#  'Запорожье': 1,
#  'Тишанский станица': 1,
#  'Бессертеневский станица': 1,
#  'Южный группа': 1,
#  'Новый александровский': 1,
#  'Богучар': 1,
#  'Дундуковый': 1,
#  'Мириада': 1,
#  'Лощинка': 1,
#  'Кумылг': 1,
#  'Татарский хутор': 1,
#  'Банальный': 1,
#  'Бахарь': 1,
#  'Осиновый пруд': 1,
#  'Дударов': 1,
#  'Солдатов': 1,
#  'Манычский': 1,
#  'Ряснянский': 1,
#  'Добрармия': 1,
#  'Тиф': 1,
#  'Махно': 1,
#  'Мурманск': 1,
#  'Архангельск': 1,
#  'Саратов': 1,
#  'Кубанский область': 1,
#  'Ставропольский губа': 1,
#  'Всевеликий войско донской': 1,
#  'Тмутаракань': 1,
#  'Войско донский': 1,
#  'Лихтенбергский': 1,
#  'Усть лабинский': 1,
#  'Ольга': 1,
#  'Евгений': 1,
#  'Темный восток': 1,
#  'Млечный шлях': 1,
#  'Марсель': 1,
#  'Андроповский': 1,
#  'Дурновский вешенский полк': 1,
#  'Область': 1,
#  'Гришка поганец': 1,
#  'Филоновский': 1,
#  'Подгорный': 1,
#  'Лукьяновский': 1,
#  'Расей': 1,
#  'Григорьева улыбка': 1,
#  'Колодезянский': 1,
#  'Мачеха': 1,
#  'Платовский станица': 1,
#  'Скважина': 1,
#  'Новороссийский гавань': 1,
#  'Монро': 1,
#  'Дюпр': 1,
#  'Фора': 1,
#  'Иловайский': 1,
#  'Денисов': 1,
#  'Кремль': 1,
#  'Мольер': 1,
#  'Тал': 1,
#  'Геок тепа': 1,
#  'Сандеп': 1,
#  'Перемышль': 1,
#  'Балканы': 1,
#  'Япония': 1,
#  'Австро венгрия': 1,
#  'Бриггс': 1,
#  'Белый ус': 1,
#  'Вешенский петро': 1,
#  'Белогорка': 1,
#  'Телеграфист мороз': 1,
#  'Олкотт': 1,
#  'Батарея': 1,
#  'Становить': 1,
#  'Усть мечетка': 1,
#  'Калачовский фронт': 1,
#  'Тринадцатый': 1,
#  'Бланк': 1,
#  'Рубежин': 1,
#  'Тамбовский губерния': 1,
#  'Рязанский губерния': 1,
#  'Верный а а а': 1,
#  'Боковский патрон': 1,
#  'Сингинский': 1,
#  'Ревтрибунал': 1,
#  'Дон улица': 1,
#  'Плешаковский': 1,
#  'Вешенский решетовец': 1,
#  'Еланский юрта': 1,
#  'Большой усть хоперский станица': 1,
#  'Степанов гимнастерка': 1,
#  'Токина': 1,
#  'Голенище': 1,
#  'Решетовский': 1,
#  'Черновский': 1,
#  'Ушаковский': 1,
#  'Дубровский': 1,
#  'Атаман': 1,
#  'Яр': 1,
#  'Матвеево курган': 1,
#  'Еланский сотня': 1,
#  'Алешка': 1,
#  'Андрюшка': 1,
#  'Антипка': 1,
#  'Хрипеть': 1,
#  'Христонина': 1,
#  'Христонин ворота': 1,
#  'Маныцков': 1,
#  'Меркулов': 1,
#  'Громковский': 1,
#  'Рыбинский': 1,
#  'Водянский': 1,
#  'Лебяжий': 1,
#  'Ерик': 1,
#  'Каргинский ревком': 1,
#  'Вислогузовский': 1,
#  'Василевка': 1,
#  'Крутенький': 1,
#  'Грековый': 1,
#  'Астахово': 1,
#  'Боковский хутор': 1,
#  'Гусынка': 1,
#  'Свиридовый': 1,
#  'Рязанский': 1,
#  'Донецкий': 1,
#  'Еланский хутор': 1,
#  'Юрта': 1,
#  'Обливать': 1,
#  'Черновский полка': 1,
#  'Татарский штокман': 1,
#  'Кривой речка': 1,
#  'Линек': 1,
#  'Андреяновский': 1,
#  'Усть медведицкий гора': 1,
#  'Усть хоперский подводчик': 1,
#  'Заамурский': 1,
#  'Еланка': 1,
#  'Зимовна': 1,
#  'Безбородов': 1,
#  'Жмеринка': 1,
#  'Крутовский гора': 1,
#  'Гусынский балка': 1,
#  'Грач': 1,
#  'Нижний латышский': 1,
#  'Забурунный лог': 1,
#  'Забурунный': 1,
#  'Чернецкая': 1,
#  'Кудинов': 1,
#  'Гришкин': 1,
#  'Рогожкинский пруд': 1,
#  'Букановский полк': 1,
#  'Заталовский': 1,
#  'Ванюшка': 1,
#  'Семушка': 1,
#  'Московский': 1,
#  'Вятский губерния': 1,
#  'Натальюшка': 1,
#  'Глядеть': 1,
#  'Еремия пророк': 1,
#  'Халдейски': 1,
#  'Вавилон': 1,
#  'Халдейск': 1,
#  'Смолоду': 1,
#  'Бахча': 1,
#  'Любомирский': 1,
#  'Советский правительство': 1,
#  'Богатырев': 1,
#  'Саратовский': 1,
#  'Самарский губерния': 1,
#  'Максаевская': 1,
#  'Антонов': 1,
#  'Сердобск': 1,
#  'Вольский уезд': 1,
#  'Калиновый угол': 1,
#  'Латышевский бугор': 1,
#  'Пономаревка': 1,
#  'Астаховый': 1,
#  'Панятный': 1,
#  'Тихон': 1,
#  'Татарский час': 1,
#  'Гундоровский': 1,
#  'Георгиевский': 1,
#  'Черноморский побережье': 1,
#  'Рязань': 1,
#  'Преображенский станица': 1,
#  'Юго восточный железный': 1,
#  'Кантемировка': 1,
#  'Вешенский дружина': 1,
#  'Чеботарев усть хоперский станица': 1,
#  'Рыбный вешенский станица': 1,
#  'Рыбный': 1,
#  'Тюковный': 1,
#  'Зимовный': 1,
#  'Баба': 1,
#  'Черный речка': 1,
#  'Большой громка': 1,
#  'Нижний кривский еланский станица': 1,
#  'Кружилинская': 1,
#  'Максаево сингинский': 1,
#  'Каргинский пеший': 1,
#  'Лиховидовский': 1,
#  'Грачевский': 1,
#  'Пегаревка': 1,
#  'Лебяжинский': 1,
#  'Задонья': 1,
#  'Белогорский гора': 1,
#  'Казанок бить': 1,
#  'Семеновский гора': 1,
#  'Белогорский': 1,
#  'Меркуловский': 1,
#  'Громковский сотня': 1,
#  'Рассохов': 1,
#  'Подстойлицей': 1,
#  'Семеновский бугор': 1,
#  'Девичий': 1,
#  'Круглый озеро': 1,
#  'Шумилинский банда': 1,
#  'Кружилин': 1,
#  'Таганрогский': 1,
#  'Дербентский': 1,
#  'Васильковский полка': 1,
#  'Придонье': 1,
#  'Нижний грушинский': 1,
#  'Трактир': 1,
#  'Али': 1,
#  'Супротив': 1,
#  'Курень': 1,
#  'Север': 1,
#  'Вешенский батарея': 1,
#  'Христос': 1,
#  'Малый громчонка': 1,
#  'Лебяженский сотня': 1,
#  'Чирский пеший': 1,
#  'Голый ильмень': 1,
#  'Черкасский помирать': 1,
#  'Безмолвие': 1,
#  'Донецкий слободка': 1,
#  'Варваринский': 1,
#  'Базковский': 1,
#  'Сулить': 1,
#  'Купеческий дом': 1,
#  'Секретев': 1,
#  'Маньчжурия': 1,
#  'Бузулук': 1,
#  'Хованский': 1,
#  'Шестой': 1,
#  'Большой сенин': 1,
#  'Усть медведицкий снаряжение': 1,
#  'Белавин': 1,
#  'Дурить': 1,
#  'Распопинский станица': 1,
#  'Повертывать': 1,
#  'Верхнедонский восстание': 1,
#  'Войсковой': 1,
#  'Сидорин высокий': 1,
#  'Индия': 1,
#  'Черкассков': 1,
#  'Повертываться круг': 1,
#  'Дарьин миска': 1,
#  'Издыхать': 1,
#  'Усть медведицкий противник': 1,
#  'Шашкино': 1,
#  'Наполовский': 1,
#  'Крикнуть': 1,
#  'Капитоновна': 1,
#  'Одуревать': 1,
#  'Тарантас': 1,
#  'Мишаткино': 1,
#  'Ярыженский': 1,
#  'Кубанский терский': 1,
#  'Борзенково': 1,
#  'Латышево': 1,
#  'Банный': 1,
#  'Саратовский укреплять район': 1,
#  'Чаплино': 1,
#  'Лозовая': 1,
#  'Врангель': 1,
#  'Кирсанов': 1,
#  'Сампур': 1,
#  'Старый оскол': 1,
#  'Средний дон': 1,
#  'Войско донской': 1,
#  'Качалинская': 1,
#  'Котлубань': 1,
#  'Балашовский фронт': 1,
#  'Баба яга': 1,
#  'Татарский вешенский станица': 1,
#  'Перевозный': 1,
#  'Лузево': 1,
#  'Ширинкин': 1,
#  'Воробьевка': 1,
#  'Кругловский': 1,
#  'Клетский': 1,
#  'Юго восточный фронт': 1,
#  'Икорец': 1,
#  'Успенский': 1,
#  'Тишанский': 1,
#  'Татарский житель': 1,
#  ...}

# %% [markdown]
# Вешенский, Вешка - это станица Вешенская, основное место действия Романа. Удалим эти 2 элемента и заменим на 1.

# %%
vesh_count=location_dict['Вешенский']+location_dict['Вешка']
vesh_count
del location_dict['Вешенский']
del location_dict['Вешка']
location_dict.update({'Вешенская':vesh_count })

# %% [markdown]
# Удалим ошибочные имена из выдачи

# %%
items_to_delete=list(['Григорий','Ильич','Ильинична','Аксинья','Ставка','Дуняшка','Прохор','Наталья','Дарья','Аксиньин','Кошевой','Офицерский союз','Астахов','Пантелей прокофиевич'])
items_to_delete

for i in range(len(items_to_delete)):
    del location_dict[items_to_delete[i]]

location_dict={k: v for k, v in sorted(location_dict.items(), key=lambda item: item[1],reverse=True)}
location_series = pd.Series(location_dict)

# %%
plt.figure(figsize=(15,8))
sns.barplot(y=location_series[0:20].index, x=location_series[0:20].values,color='blue')
plt.title("Частотность употребления глаголов")
plt.show()

# %% [markdown]
# Как видим, основное действие связяно с рекой Дон, станицей Вешенская, станицами, хуторами и городами поблизости. Остальные крупные города были местомо действия исторических отсылок.
# В принципе можно отфильтровать общие места вроде России, Дона, Кубани - что по сути означало наименование широких географических областей.

# %% [markdown]
# #### Части речи (PoS)

# %% [markdown]
# Посмотрим наиболее частые глаголы (кроме исключенных в стоп - словах)

# %%
#Используем эту ячейку чтобы не повторять лемматизацию постоянно
corpus_df=pd.read_csv("C:\\Users\\Admin\\Python+ DS Practice\\Яндекс Новости\\df_tihij_don.csv",encoding = 'cp1251',sep=',', error_bad_lines=False)
#В конце текста идут сноски, не будем их брать
corpus_df=corpus_df.loc[0:19719]
#Удалим пропуски
corpus_df=corpus_df.dropna()
len(corpus_df)
#Переведем корпус в np.array
corpus=corpus_df.values.astype('U')
corpus=corpus.reshape(18982,)
#corpus.shape
#Переведем корпус в np.array
corpus=corpus_df.values.astype('U')
corpus=corpus.reshape(18982,)
corpus.shape
# Out:
# (18982,)

# %%
stop_words = set(stopwords.words('russian'))
print(len(stop_words))
#Добавим в стоп слова слова полученные эмпирическим путем
custom_stopwords = set(['это','весь','яя','ая','га','свой','спрашивать','становиться','отвечать','подходить','уходить','выходить','оставаться','разговор','ехать','приходить'])
print(len(custom_stopwords))
stop_words.update(custom_stopwords)
#Проверим результат обновления множества
print(len(stop_words))
# Out:
# 151
# 16
# 167

# %%
#Добавим имена главныъ героев в словарь.
main_characters = set(['григорий','аксинья','пантелей','прокофиевич','иван','алексеевич','мирон','григорьевич','сергей','платонович','гришак','пантелевич','кошевой','мишка','мелехов','прохор','зыков','митька','коршунов','сашка','степан','астахов','наталья','петро','ильинична','дуняшка','бунчук','фомин','дарья','листницкий'])

# %%
#В данной работе главные герои нас не интересуют, уберем их
stop_words.update(main_characters)

# %%
#стоп слова из интернета вопрос спроный. Например убирая слово "ваше", мы теряем фразу "ваше благородие", т.е. часть авторского стиля. 
# В дальнейшем можно вернуться к этому моменту
stopwords_from_internet_1=set(["c","а","алло","без","белый","близко","более","больше","большой","будем","будет","будете","будешь","будто","буду","будут","будь","бы","бывает","бывь","был","была","были","было","быть","в","важная","важное","важные","важный","вам","вами","вас","ваш","ваша","ваше","ваши","вверх","вдали","вдруг","ведь","везде","вернуться","весь","вечер","взгляд","взять","вид","видел","видеть","вместе","вне","вниз","внизу","во","вода","война","вокруг","вон","вообще","вопрос","восемнадцатый","восемнадцать","восемь","восьмой","вот","впрочем","времени","время","все","все еще","всегда","всего","всем","всеми","всему","всех","всею","всю","всюду","вся","всё","второй","вы","выйти","г","где","главный","глаз","говорил","говорит","говорить","год","года","году","голова","голос","город","да","давать","давно","даже","далекий","далеко","дальше","даром","дать","два","двадцатый","двадцать","две","двенадцатый","двенадцать","дверь","двух","девятнадцатый","девятнадцать","девятый","девять","действительно","дел","делал","делать","делаю","дело","день","деньги","десятый","десять","для","до","довольно","долго","должен","должно","должный","дом","дорога","друг","другая","другие","других","друго","другое","другой","думать","душа","е","его","ее","ей","ему","если","есть","еще","ещё","ею","её","ж","ждать","же","жена","женщина","жизнь","жить","за","занят","занята","занято","заняты","затем","зато","зачем","здесь","земля","знать","значит","значить","и","иди","идти","из","или","им","имеет","имел","именно","иметь","ими","имя","иногда","их","к","каждая","каждое","каждые","каждый","кажется","казаться","как","какая","какой","кем","книга","когда","кого","ком","комната","кому","конец","конечно","которая","которого","которой","которые","который","которых","кроме","кругом","кто","куда","лежать","лет","ли","лицо","лишь","лучше","любить","люди","м","маленький","мало","мать","машина","между","меля","менее","меньше","меня","место","миллионов","мимо","минута","мир","мира","мне","много","многочисленная","многочисленное","многочисленные","многочисленный","мной","мною","мог","могу","могут","мож","может","может быть","можно","можхо","мои","мой","мор","мочь","моя","моё","мы","на","наверху","над","надо","назад","наиболее","найти","наконец","нам","нами","народ","нас","начала","начать","наш","наша","наше","наши","не","него","недавно","недалеко","нее","ней","некоторый","нельзя","нем","немного","нему","непрерывно","нередко","несколько","нет","нею","неё","ни","нибудь","ниже","низко","никакой","никогда","никто","никуда","ним","ними","них","ничего","ничто","но","новый","нога","ночь","ну","нужно","нужный","нх","о","об","оба","обычно","один","одиннадцатый","одиннадцать","однажды","однако","одного","одной","оказаться","окно","около","он","она","они","оно","опять","особенно","остаться","от","ответить","отец","откуда","отовсюду","отсюда","очень","первый","перед","писать","плечо","по","под","подойди","подумать","пожалуйста","позже","пойти","пока","пол","получить","помнить","понимать","понять","пор","пора","после","последний","посмотреть","посреди","потом","потому","почему","почти","правда","прекрасно","при","про","просто","против","процентов","путь","пятнадцатый","пятнадцать","пятый","пять","работа","работать","раз","разве","рано","раньше","ребенок","решить","россия","рука","русский","ряд","рядом","с","с кем","сам","сама","сами","самим","самими","самих","само","самого","самой","самом","самому","саму","самый","свет","свое","своего","своей","свои","своих","свой","свою","сделать","сеаой","себе","себя","сегодня","седьмой","сейчас","семнадцатый","семнадцать","семь","сидеть","сила","сих","сказал","сказала","сказать","сколько","слишком","слово","случай","смотреть","сначала","снова","со","собой","собою","советский","совсем","спасибо","спросить","сразу","стал","старый","стать","стол","сторона","стоять","страна","суть","считать","т","та","так","такая","также","таки","такие","такое","такой","там","твои","твой","твоя","твоё","те","тебе","тебя","тем","теми","теперь","тех","то","тобой","тобою","товарищ","тогда","того","тоже","только","том","тому","тот","тою","третий","три","тринадцатый","тринадцать","ту","туда","тут","ты","тысяч","у","увидеть","уж","уже","улица","уметь","утро","хороший","хорошо","хотел бы","хотеть","хоть","хотя","хочешь","час","часто","часть","чаще","чего","человек","чем","чему","через","четвертый","четыре","четырнадцатый","четырнадцать","что","чтоб","чтобы","чуть","шестнадцатый","шестнадцать","шестой","шесть","эта","эти","этим","этими","этих","это","этого","этой","этом","этому","этот","эту","я","являюсь"])
stop_words.update(stopwords_from_internet_1)

# %%
count_vect = CountVectorizer(stop_words=stop_words) 
bow = count_vect.fit_transform(corpus) 

print("Размер мешка без учёта стоп-слов:", bow.shape)
#count_vect.get_feature_names() 
word_list=count_vect.get_feature_names() 
count_list = bow.toarray().sum(axis=0)
x = dict(zip(word_list,count_list))
{k: v for k, v in sorted(x.items(), key=lambda item: item[1],reverse=True)}
g={k: v for k, v in sorted(x.items(), key=lambda item: item[1],reverse=True)}
result_series = pd.Series(g)
dict_for_test=result_series.to_dict()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:388: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['хотел'] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# Размер мешка без учёта стоп-слов: (18982, 26062)

# %%
verb_series=dict()
for i in tqdm(dict_for_test.keys()):
    doc=nlp(i)
    for token in doc:
        if token.pos_ =='VERB':
            verb_series.update({i:dict_for_test[i]})
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 26062/26062 [01:36<00:00, 269.28it/s]

# %%
verb_series
#Сортируем по убыванию частотности
verb_dict={k: v for k, v in sorted(verb_series.items(), key=lambda item: item[1],reverse=True)}
verb_pd_series = pd.Series(verb_dict)

# %%
plt.figure(figsize=(15,8))
sns.barplot(x=verb_pd_series[0:20].index, y=verb_pd_series[0:20].values,color='blue')
plt.title("Частотность употребления глаголов")
plt.show()

# %%
#Можно обновить список стоп-слов - приезжать, поехать, входить,спать,начинать, нету.
#Можно оставить пока так до сравнения с другими книгами

# %%
verbs_to_delete=list(['приезжать','поехать','входить','спать','начинать','нету','ходить','проходить'])
verbs_to_delete

for i in range(len(verbs_to_delete)):
    del verb_dict[verbs_to_delete[i]]
    #del propn_dict(items_to_delete[i])
#del propn_dict['Ильич']

#propn_dict
verb_dict={k: v for k, v in sorted(verb_dict.items(), key=lambda item: item[1],reverse=True)}
verb_pd_series = pd.Series(verb_dict)

plt.figure(figsize=(15,8))
sns.barplot(x=verb_pd_series[0:20].index, y=verb_pd_series[0:20].values,color='blue')
plt.title("Частотность употребления глаголов")
plt.show()

# %% [markdown]
# #### Выводы

# %% [markdown]
# 1.В данной работе были исследованы инструменты для выполнения актуальных задач для NLP - POS-тэггинг, NER.<br>
# 2.Требуется объемная ручная обработка, так как библиотека spacy не всегда верно распознает географические точки, вставляя в них имена героев. Поэтому без знания книги, текст не обработать автоматически. С другой стороны, книге около 100 лет, и то что добавляются лишние сущности лучше чем если бы они пропускались вовсе.<br>
# 3.В дальнейшем можно сравнить данный анализ с анализом по книге Шолохова "Донские рассказы" и найти схожести в описании, чтобы ответить на вопрос об авторстве книг.
